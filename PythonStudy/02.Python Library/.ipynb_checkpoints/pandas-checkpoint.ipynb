# %%
import pandas as pd

# %% [markdown]
# ![image.png](attachment:7b8ae498-ecfd-4a5e-a783-aee16b759ca2.png)

# %%
s1 = pd.Series([1,2,3,4,5])
print(s1)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
s2 = pd.Series([0,9,8,7,6], index=['a','b','c','d','e'])
print(s2)
# Out:
# a    0
# b    9
# c    8
# d    7
# e    6
# dtype: int64

# %%
s3 = pd.Series({'a' : 1, 'b':2, 'c' :3})
print(s3)
# Out:
# a    1
# b    2
# c    3
# dtype: int64

# %%
print(s3.values)
print(s3.index)
# Out:
# [1 2 3]
# Index(['a', 'b', 'c'], dtype='object')

# %%
s3.index.name = 'alpa'
print(s3)
# Out:
# alpa
# a    1
# b    2
# c    3
# dtype: int64

# %%
s4 = pd.Series({'서울' : 9602000 ,'부산' : 3344000, '광주' : 1488000, '대구' : 2419000})
s4.index.name = '도시'
s4.name = '2020 인구수'
print(s4)
# Out:
# 도시
# 서울    9602000
# 부산    3344000
# 광주    1488000
# 대구    2419000
# Name: 2020 인구수, dtype: int64

# %%
s4['서울'] = 9700000
print(s4)
# Out:
# 도시
# 서울    9700000
# 부산    3344000
# 광주    1488000
# 대구    2419000
# Name: 2020 인구수, dtype: int64

# %%
s4['대전'] = 1234510
print(s4)
# Out:
# 도시
# 서울    9700000
# 부산    3344000
# 광주    1488000
# 대구    2419000
# 대전    1234510
# Name: 2020 인구수, dtype: int64

# %%
del s4['대전']
print(s4)
# Out:
# 도시
# 서울    9700000
# 부산    3344000
# 광주    1488000
# 대구    2419000
# Name: 2020 인구수, dtype: int64

# %%
print(s4[:])
# Out:
# 도시
# 서울    9700000
# 부산    3344000
# 광주    1488000
# 대구    2419000
# Name: 2020 인구수, dtype: int64

# %%
print(s4[0])
print(s4['서울'])
# Out:
# 9700000
# 9700000

# %%
s4 >= 2000000
# Out:
# 도시
# 서울     True
# 부산     True
# 광주    False
# 대구     True
# Name: 2020 인구수, dtype: bool

# %%
s4[s4>=2000000]
# Out:
# 도시
# 서울    9700000
# 부산    3344000
# 대구    2419000
# Name: 2020 인구수, dtype: int64

# %%
num_list =[1,2,3,4,5]
num_pd = pd.DataFrame(num_list)
num_pd
# Out:
#    0
# 0  1
# 1  2
# 2  3
# 3  4
# 4  5

# %%
num_list2 = [[1,2,3],[4,5,6]]
num_pd2 = pd.DataFrame(num_list2)
num_pd2
# Out:
#    0  1  2
# 0  1  2  3
# 1  4  5  6

# %%
score_list = [['java',90],['python',80],['c',70]]
score_pd = pd.DataFrame(score_list)
score_pd
# Out:
#         0   1
# 0    java  90
# 1  python  80
# 2       c  70

# %%
score_list = [['java',90],['python',80],['c',70]]
score_pd = pd.DataFrame(score_list, columns = ['과목명', '점수'], index=['1과목','2과목','3과목'])
score_pd
# Out:
#         과목명  점수
# 1과목    java  90
# 2과목  python  80
# 3과목       c  70

# %%
score_pd2 = pd.DataFrame({'과목명' : ['java','python','c'],'점수': [90,85,80]})
score_pd2
# Out:
#       과목명  점수
# 0    java  90
# 1  python  85
# 2       c  80

# %%
score_pd2.values
# Out:
# array([['java', 90],
#        ['python', 85],
#        ['c', 80]], dtype=object)

# %%
score_pd2.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
score_pd2.columns
# Out:
# Index(['과목명', '점수'], dtype='object')

# %%
person_info = pd.DataFrame({'키':[175.3,180.2,178.6],'몸무게':[66.2,78.9,55.1],'나이':[27.0,49.0,35.0]},
                       index= ['son','kim','park'])
person_info
# Out:
#           키   몸무게    나이
# son   175.3  66.2  27.0
# kim   180.2  78.9  49.0
# park  178.6  55.1  35.0

# %%
person_info.dtypes
# Out:
# 키      float64
# 몸무게    float64
# 나이     float64
# dtype: object

# %%
person_info.T
# Out:
#        son    kim   park
# 키    175.3  180.2  178.6
# 몸무게   66.2   78.9   55.1
# 나이    27.0   49.0   35.0

# %%
person_info.T.T
# Out:
#           키   몸무게    나이
# son   175.3  66.2  27.0
# kim   180.2  78.9  49.0
# park  178.6  55.1  35.0

# %%
person_info['키']
# Out:
# son     175.3
# kim     180.2
# park    178.6
# Name: 키, dtype: float64

# %%
person_info[['키','나이']]
# Out:
#           키    나이
# son   175.3  27.0
# kim   180.2  49.0
# park  178.6  35.0

# %%
person_info.columns[0]
# Out:
# '키'

# %%
person_info[:2]
# Out:
#          키   몸무게    나이
# son  175.3  66.2  27.0
# kim  180.2  78.9  49.0

# %%
person_info['son':]
# Out:
#           키   몸무게    나이
# son   175.3  66.2  27.0
# kim   180.2  78.9  49.0
# park  178.6  55.1  35.0

# %%
person_info.loc['son']
# Out:
# 키      175.3
# 몸무게     66.2
# 나이      27.0
# Name: son, dtype: float64

# %%
person_info.loc['son':'kim']
# Out:
#          키   몸무게    나이
# son  175.3  66.2  27.0
# kim  180.2  78.9  49.0

# %%
person_info.loc[:'kim', '몸무게' : ]
# Out:
#       몸무게    나이
# son  66.2  27.0
# kim  78.9  49.0

# %%
person_info.iloc[:2]
# Out:
#          키   몸무게    나이
# son  175.3  66.2  27.0
# kim  180.2  78.9  49.0

# %%
person_info.iloc[0,0]
# Out:
# 175.3

# %%
person_info.iloc[:2,1:]
# Out:
#       몸무게    나이
# son  66.2  27.0
# kim  78.9  49.0

# %%
person_info['키'] >= 180
# Out:
# son     False
# kim      True
# park    False
# Name: 키, dtype: bool

# %%
person_info[person_info['키'] >= 180]
# Out:
#          키   몸무게    나이
# kim  180.2  78.9  49.0

# %%
person_info.query('키 >= 180')
# Out:
#          키   몸무게    나이
# kim  180.2  78.9  49.0
