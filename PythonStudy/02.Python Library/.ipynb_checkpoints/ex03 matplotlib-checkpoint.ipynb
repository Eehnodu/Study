# %% [markdown]
# ![image.png](attachment:147e33a7-1c53-46af-95ee-30f8cfe13181.png)
# ![image.png](attachment:954851f4-2d7b-49de-9536-29f81c93ebd0.png)
# ![image.png](attachment:900bfc07-3efc-439d-bab1-69112d735466.png)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# 배열 생성하여 데이터 준비
x = np.arange(1,6)
np.random.seed(3)
y = np.random.randint(1,10,size=5)
print(x)
print(y)
# Out:
# [1 2 3 4 5]
# [9 4 9 9 1]

# %%
plt.plot(x,y)
plt.show()

# %%
plt.plot(y)
plt.show()

# %% [markdown]
# ![image.png](attachment:f3303e9f-69f4-4ec7-a1a5-64e535edc1c8.png)
# ![image.png](attachment:5c2d6555-3621-42ac-afb9-4efd3955df6c.png)
# ![image.png](attachment:5efef45c-8399-48b8-bd74-107966ffec5d.png)

# %%
plt.plot(x,y, marker = 'o', ms = 3, c = 'purple', mec='k', mew=7, mfc = 'w')
plt.show()

# %%
plt.plot(x,y, ls = '-', color='b' ,marker='D', ms=10, mec='c',mew=4, mfc='y')
plt.plot(x,y, ls = '--', color='m', lw=5)
plt.plot(x,y, ls = '-.')
plt.plot(x,y, ls = ':')
plt.show()

# %%
plt.subplot(3,2,1)
plt.plot(x,y, ls = '-', color='b' ,marker='D', ms=10, mec='c',mew=4, mfc='y')
plt.subplot(3,2,2)
plt.plot(x,y, ls = '--', color='m', lw=5)
plt.subplot(3,2,3)
plt.plot(x,y, ls = '-.')
plt.subplot(3,2,4)
plt.plot(x,y, ls = ':')
plt.subplot(3,2,5)
plt.plot(x,y, ls = ':')
plt.subplot(3,2,6)
plt.plot(x,y, ls = ':')
plt.show()

# %% [markdown]
# ![image.png](attachment:b704f2de-9d45-4c28-ba03-1b36b02aa115.png)

# %%
#한글 폰트 깨질 경우
plt.rcParams['font.family'] = 'Malgun Gothic'
plt.figure(figsize=(5,3))
# 배열 생성하여 데이터 준비
test_x = np.arange(0,6)
np.random.seed(4)
test_y = np.random.randint(1,10,size=6)
plt.plot(test_x, test_y, label = 'test')
test_x1 = np.arange(0,6)
np.random.seed(10)
test_y1 = np.random.randint(1,10,size=6)
plt.plot(test_x1, test_y1, label = 'test1')

plt.legend()
plt.xlabel('x축')
plt.ylabel('y축', rotation = 0)
plt.xlim(0,5)
plt.ylim(0,10)
plt.xticks([1,2,3,4,5])
plt.yticks([1,3,5,7,9,11])
plt.title("그래프")
plt.grid()
plt.show()

# %%
data = pd.read_csv('../data/장래_인구변동_KOSIS.csv', encoding = 'euc-kr', index_col = '인구변동요인별')
data
# Out:
#            2020   2030   2040   2050   2060   2070
# 인구변동요인별
# 인구(천명)    51836  51199  50193  47359  42617  37656
# 출생아수(천명)    275    305    286    236    181    196
# 사망자수(천명)    308    408    527    680    741    702

# %%
data_y1 = data.iloc[1]
data_y2 = data.iloc[2]
data_x = data.columns
print(data_x)
# Out:
# Index(['2020', '2030', '2040', '2050', '2060', '2070'], dtype='object')

# %%
plt.plot(data_x, data_y1, marker='*', ms=10, label = '출생아수(천명)')
plt.plot(data_x, data_y2, marker='o', ms=8, label = '사망자수(천명)')
plt.title("국가통계 요인별 장래 인구 동향")
plt.legend()
plt.xlabel('x축')
plt.ylabel('y축', rotation = 0)
plt.grid()
# plt.show()
plt.savefig('kosis 요인별 장래 인구 동향.png', dpi=600, bbox_inches='tight')

# %%
kma = pd.read_csv('../data/기상청.csv', encoding = 'euc-kr', skiprows=range(0,7))
kma.head(5)
# Out:
#              날짜   지점  평균기온(℃)  최저기온(℃)  최고기온(℃)
# 0  \t2010-01-01  156     -3.6     -9.5      1.9
# 1  \t2010-01-02  156      1.6     -3.9      6.6
# 2  \t2010-01-03  156      0.4     -1.8      3.5
# 3  \t2010-01-04  156      0.5     -1.8      5.7
# 4  \t2010-01-05  156     -3.0     -4.9      0.2

# %%
kma_mean = kma.iloc[:,2]
kma_min = kma.iloc[:,3]
kma_max = kma.iloc[:,4]
kma_date = kma.iloc[:,0].str.strip('\t')

# %%
plt.rcParams['axes.unicode_minus'] = False
t_y = kma['최고기온(℃)']
plt.plot(t_y)
plt.show()

# %%
kma['년'] = kma['날짜'].str[1:5]
kma['월일'] = kma['날짜'].str[-5:]
kma
# Out:
#                 날짜   지점  평균기온(℃)  최저기온(℃)  최고기온(℃)     년     월일
# 0     \t2010-01-01  156     -3.6     -9.5      1.9  2010  01-01
# 1     \t2010-01-02  156      1.6     -3.9      6.6  2010  01-02
# 2     \t2010-01-03  156      0.4     -1.8      3.5  2010  01-03
# 3     \t2010-01-04  156      0.5     -1.8      5.7  2010  01-04
# 4     \t2010-01-05  156     -3.0     -4.9      0.2  2010  01-05
# ...            ...  ...      ...      ...      ...   ...    ...
# 5154  \t2024-02-11  156      3.2     -1.2      9.1  2024  02-11
# 5155  \t2024-02-12  156      5.8     -0.9     13.0  2024  02-12
# 5156  \t2024-02-13  156     10.6      3.4     17.6  2024  02-13
# 5157  \t2024-02-14  156     13.5     10.6     19.0  2024  02-14
# 5158  \t2024-02-15  156      6.4      0.5     12.4  2024  02-15
#
# [5159 rows x 7 columns]

# %%
birthday_data = kma.query('월일=="07-19"')
birthday_data
# Out:
#                 날짜   지점  평균기온(℃)  최저기온(℃)  최고기온(℃)     년     월일
# 199   \t2010-07-19  156     28.1     25.3     32.5  2010  07-19
# 564   \t2011-07-19  156     30.2     25.4     35.3  2011  07-19
# 930   \t2012-07-19  156     26.4     23.7     30.6  2012  07-19
# 1295  \t2013-07-19  156     28.1     23.5     33.0  2013  07-19
# 1660  \t2014-07-19  156     25.0     21.8     30.7  2014  07-19
# 2025  \t2015-07-19  156     26.9     22.1     32.1  2015  07-19
# 2391  \t2016-07-19  156     26.9     22.1     31.7  2016  07-19
# 2756  \t2017-07-19  156     28.7     24.8     33.7  2017  07-19
# 3121  \t2018-07-19  156     29.5     25.2     35.5  2018  07-19
# 3486  \t2019-07-19  156     24.8     22.7     27.3  2019  07-19
# 3852  \t2020-07-19  156     26.2     23.3     28.8  2020  07-19
# 4217  \t2021-07-19  156     27.8     24.1     32.5  2021  07-19
# 4582  \t2022-07-19  156     26.2     22.8     30.7  2022  07-19
# 4947  \t2023-07-19  156     26.2     23.5     30.8  2023  07-19

# %%
birthday_y1 = birthday_data['평균기온(℃)']
birthday_x1 = birthday_data['년']
plt.plot(birthday_x1, birthday_y1)
plt.show()

# %%
# 데이터의 빈도를 막대 그래프 형태로 표시한 것# 주사위를 100번 던져서 나오는 수들의 분포를 히스토그램으로 그려보기
np.random.seed(3)
a = np.random.randint(1,7, size = 100)
np.unique(a, return_counts=True) 
plt.hist(a, bins = 6)
plt.show()

# %%
kma['월'] = kma['날짜'].str[-5:-3]
kma['일'] = kma['날짜'].str[-2:]
kma
# Out:
#                 날짜   지점  평균기온(℃)  최저기온(℃)  최고기온(℃)     년     월일   월   일
# 0     \t2010-01-01  156     -3.6     -9.5      1.9  2010  01-01  01  01
# 1     \t2010-01-02  156      1.6     -3.9      6.6  2010  01-02  01  02
# 2     \t2010-01-03  156      0.4     -1.8      3.5  2010  01-03  01  03
# 3     \t2010-01-04  156      0.5     -1.8      5.7  2010  01-04  01  04
# 4     \t2010-01-05  156     -3.0     -4.9      0.2  2010  01-05  01  05
# ...            ...  ...      ...      ...      ...   ...    ...  ..  ..
# 5154  \t2024-02-11  156      3.2     -1.2      9.1  2024  02-11  02  11
# 5155  \t2024-02-12  156      5.8     -0.9     13.0  2024  02-12  02  12
# 5156  \t2024-02-13  156     10.6      3.4     17.6  2024  02-13  02  13
# 5157  \t2024-02-14  156     13.5     10.6     19.0  2024  02-14  02  14
# 5158  \t2024-02-15  156      6.4      0.5     12.4  2024  02-15  02  15
#
# [5159 rows x 9 columns]

# %%
date_02 = kma.query('월 == "02"')
max_temp_02 = date_02['최고기온(℃)']
min_temp_02 = date_02['최저기온(℃)']

# %%
plt.hist(max_temp_02, bins = 100)
plt.show()

# %%
plt.hist(max_temp_02, bins = 100, color = 'red', alpha = 0.7,label='최고기온(℃)')
plt.hist(min_temp_02, bins = 100, color = 'orange', alpha = 0.7,label='최저기온(℃)')
plt.title('2월 최저/최고 기온')
plt.xlabel('온도(℃)')
plt.ylabel('빈도수')
plt.legend()
plt.show()

# %%
# 1D 데이터 준비하여 박스 플롯 그려보기
np.random.seed(1)
tmp_data = np.random.randint(10,size = 10)
# print(tmp_data)
# tmp_data= np.append(tmp_data, 20)
# print(tmp_data)
plt.boxplot(tmp_data, labels=['데이터명'])
plt.show()

# %%
date_02[date_02['평균기온(℃)'] < -5]
# Out:
#                 날짜   지점  평균기온(℃)  최저기온(℃)  최고기온(℃)     년     월일   월   일
# 762   \t2012-02-02  156     -7.9     -9.7     -5.2  2012  02-02  02  02
# 768   \t2012-02-08  156     -5.7     -9.3     -2.0  2012  02-08  02  08
# 1134  \t2013-02-08  156     -6.3     -9.7     -1.4  2013  02-08  02  08
# 2956  \t2018-02-04  156     -5.9     -8.3     -3.0  2018  02-04  02  04
# 2957  \t2018-02-05  156     -5.6     -8.5     -1.7  2018  02-05  02  05
# 2958  \t2018-02-06  156     -6.5     -9.8     -2.8  2018  02-06  02  06

# %%
plt.boxplot(date_02['평균기온(℃)'], labels=['평균기온(℃)'])
plt.show()

# %%
# 데이터 준비하여 막대 그래프 그려보기
np.random.seed(6)
bar_x = np.arange(1,4)
bar_y = np.random.randint(50,100,size=3)

plt.bar(bar_x,bar_y)
plt.show()

# %%
# https://matplotlib.org/stable/gallery/color/named_colors.html#base-colors  doc제공 코드
import math
from matplotlib.patches import Rectangle
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors


def plot_colortable(colors, *, ncols=4, sort_colors=True):

    cell_width = 212
    cell_height = 22
    swatch_width = 48
    margin = 12

    # Sort colors by hue, saturation, value and name.
    if sort_colors is True:
        names = sorted(
            colors, key=lambda c: tuple(mcolors.rgb_to_hsv(mcolors.to_rgb(c))))
    else:
        names = list(colors)

    n = len(names)
    nrows = math.ceil(n / ncols)

    width = cell_width * 4 + 2 * margin
    height = cell_height * nrows + 2 * margin
    dpi = 72

    fig, ax = plt.subplots(figsize=(width / dpi, height / dpi), dpi=dpi)
    fig.subplots_adjust(margin/width, margin/height,
                        (width-margin)/width, (height-margin)/height)
    ax.set_xlim(0, cell_width * 4)
    ax.set_ylim(cell_height * (nrows-0.5), -cell_height/2.)
    ax.yaxis.set_visible(False)
    ax.xaxis.set_visible(False)
    ax.set_axis_off()

    for i, name in enumerate(names):
        row = i % nrows
        col = i // nrows
        y = row * cell_height

        swatch_start_x = cell_width * col
        text_pos_x = cell_width * col + swatch_width + 7

        ax.text(text_pos_x, y, name, fontsize=14,
                horizontalalignment='left',
                verticalalignment='center')

        ax.add_patch(
            Rectangle(xy=(swatch_start_x, y-9), width=swatch_width,
                      height=18, facecolor=colors[name], edgecolor='0.7')
        )

    return fig
plot_colortable(mcolors.CSS4_COLORS)
plt.show()

# %%
print(bar_x)
# Out:
# [1 2 3]

# %%
plt.bar(bar_x,bar_y, color = ['hotpink','deeppink','pink'])
# plt.text(2,59, '59', fontdict = {'color' : 'black', 'size' : 15})
# plt.text(1,60, '60', fontdict = {'color' : 'black', 'size' : 15})
# plt.text(3.93,85, '85', fontdict = {'color' : 'black', 'size' : 15})

for i in range(len(bar_x)):
    plt.text(bar_x[i], bar_y[i], bar_y[i], fontdict = {'color' : 'black', 'size' : 15}, ha = 'center',va = 'baseline')
plt.show()

# %%
economic = pd.read_csv('../data/시도_성별_경제활동인구_총괄_KOSIS_2022.csv', encoding = 'euc-kr')
economic.head()
# Out:
#   행정구역(시도)  성별  15세이상인구 (천명)  경제활동인구 (천명)  취업자 (천명)  실업자 (천명)  비경제활동인구 (천명)  \
# 0    서울특별시  남자          4007         2849      2760        89          1158
# 1    서울특별시  여자          4440         2418      2347        72          2022
# 2    부산광역시  남자          1406          973       946        27           433
# 3    부산광역시  여자          1528          768       745        23           760
# 4    대구광역시  남자          1001          708       691        17           294
#
#    경제활동참가율(％)  고용률(%)  실업률(%)
# 0        71.1    68.9     3.1
# 1        54.5     NaN     3.0
# 2        69.2    67.3     2.7
# 3        50.3    48.8     3.0
# 4        70.6    69.0     2.3

# %%
economic['고용률(%)']
economic['고용률(%)'] = economic['취업자 (천명)'] / economic['15세이상인구 (천명)'] * 100
economic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34 entries, 0 to 33
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   행정구역(시도)      34 non-null     object
#  1   성별            34 non-null     object
#  2   15세이상인구 (천명)  34 non-null     int64
#  3   경제활동인구 (천명)   34 non-null     int64
#  4   취업자 (천명)      34 non-null     int64
#  5   실업자 (천명)      34 non-null     int64
#  6   비경제활동인구 (천명)  34 non-null     int64
#  7   경제활동참가율(％)    34 non-null     float64
#  8   고용률(%)        34 non-null     float64
#  9   실업률(%)        28 non-null     float64
# dtypes: float64(3), int64(5), object(2)
# memory usage: 2.8+ KB

# %% [markdown]
# ### 종합실습
# - 전국 교토사고 2017년 데이터를 이용해서 시각화 작업을 해보자

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

accident = pd.read_csv('../data/Traffic_Accident_2017.csv', encoding = 'euc-kr')
accident.head(3)
# Out:
#     발생년      발생년월일시  발생분  주야 요일  사망자수  사상자수  중상자수  경상자수  부상신고자수  ... 도로형태_대분류  \
# 0  2017  2017010101   15  야간  일     1     2     1     0       0  ...      단일로
# 1  2017  2017010102   28  야간  일     1     1     0     0       0  ...      교차로
# 2  2017  2017010102   43  야간  일     1     2     0     1       0  ...      단일로
#
#     도로형태 당사자종별_1당_대분류 당사자종별_1당 당사자종별_2당_대분류 당사자종별_2당 발생위치X_UTMK 발생위치Y_UTMK  \
# 0  기타단일로          승용차      승용차          승용차      승용차     933501    1700129
# 1  교차로부근          승용차      승용차          보행자      보행자     967570    1944453
# 2  기타단일로          승용차      승용차          승용차      승용차     916497    1842880
#
#            경도         위도
# 0  126.768634  35.294464
# 1  127.133107  37.498741
# 2  126.566631  36.580069
#
# [3 rows x 27 columns]

# %%
accident.columns
# Out:
# Index(['발생년', '발생년월일시', '발생분', '주야', '요일', '사망자수', '사상자수', '중상자수', '경상자수',
#        '부상신고자수', '발생지시도', '발생지시군구', '사고유형_대분류', '사고유형_중분류', '사고유형', '법규위반_대분류',
#        '법규위반', '도로형태_대분류', '도로형태', '당사자종별_1당_대분류', '당사자종별_1당', '당사자종별_2당_대분류',
#        '당사자종별_2당', '발생위치X_UTMK', '발생위치Y_UTMK', '경도', '위도'],
#       dtype='object')

# %%
tmp = accident['요일'].value_counts()
y = tmp[['월','화','수','목','금','토','일']]
y
# Out:
# 요일
# 월    603
# 화    608
# 수    565
# 목    586
# 금    603
# 토    596
# 일    504
# Name: count, dtype: int64

# %%
plt.rcParams['font.family'] = 'Malgun Gothic'
x = y.index
plt.bar(x,y)
plt.title('요일별 사고 건수')
plt.xlabel('요일')
plt.ylabel('사고 건수' , rotation = 0)
plt.ylim(500, 625)
plt.show()

# %%
plt.barh(y,x)
# Out:
# <BarContainer object of 7 artists>

# %% [markdown]
# ### 종합 연습문제2
# - 차대차 사건중 죽거나 다친사람이 많은 발생지 시도별 시각화 진행

# %%
ctc= accident[accident['사고유형_대분류'] == '차대차']
ctc
# Out:
#        발생년      발생년월일시  발생분  주야 요일  사망자수  사상자수  중상자수  경상자수  부상신고자수  ...  \
# 0     2017  2017010101   15  야간  일     1     2     1     0       0  ...
# 2     2017  2017010102   43  야간  일     1     2     0     1       0  ...
# 8     2017  2017010118   33  야간  일     1     3     1     1       0  ...
# 9     2017  2017010120    0  야간  일     1     7     4     2       0  ...
# 17    2017  2017010209    0  주간  월     1     2     1     0       0  ...
# ...    ...         ...  ...  .. ..   ...   ...   ...   ...     ...  ...
# 4050  2017  2017123009   58  주간  토     1     1     0     0       0  ...
# 4055  2017  2017123023   50  야간  토     1     6     2     3       0  ...
# 4058  2017  2017123112   10  주간  일     1     1     0     0       0  ...
# 4060  2017  2017123118   10  야간  일     1     4     1     0       2  ...
# 4063  2017  2017123120   40  야간  일     1    11     1     9       0  ...
#
#      도로형태_대분류   도로형태 당사자종별_1당_대분류 당사자종별_1당 당사자종별_2당_대분류 당사자종별_2당 발생위치X_UTMK  \
# ...

# %%
ctc['사고유형_대분류'].value_counts()
# Out:
# 사고유형_대분류
# 차대차    1642
# Name: count, dtype: int64
