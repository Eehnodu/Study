# %% [markdown]
# ## 목표
# - 비정형 데이터끼리 유사도를 비교하는 방법을 알아보자
# - case 1 : 빈도기반의 전처리 도구와 유사도 알고리즘을 이용한 방법
# - case 2 : 딥러닝기반의 모델을 활용한 유사도 비교(word2vec,k doc2vec)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from tqdm import tqdm

# %% [markdown]
# #### 데이터로딩

# %%
data = pd.read_csv('data/dart.csv')
data.head()
# Out:
#      code market   name                                           business
# 0  000020  KOSPI   동화약품  II. 사업의 내용\n1. 사업의 개요\n가. 일반적인 사항\n기업회계기준서 제11...
# 1  000040  KOSPI  KR모터스  II. 사업의 내용\n1. 사업의 개요\n가. 업계의 현황\n수출주력시장인 유럽 불...
# 2  000050  KOSPI     경방  II. 사업의 내용\n1. 사업의 개요\n(1) 산업의 특성\n[섬유사업부문]\n면...
# 3  000060  KOSPI  메리츠화재  II. 사업의 내용\n1. 사업의 개요\n가. 산업의 특성, 성장성, 경기변동의 특...
# 4  000070  KOSPI  삼양홀딩스  II. 사업의 내용\n1. 사업의 개요\n가. 업계의 현황\n지주회사(持株會社, H...

# %%
business = data['business']
name = data['name']

# %%
print(business.shape, name.shape)
# Out:
# (2589,) (2589,)

# %%
# 결측치 확인
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2589 entries, 0 to 2588
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   code      2589 non-null   object
#  1   market    2589 non-null   object
#  2   name      2589 non-null   object
#  3   business  2295 non-null   object
# dtypes: object(4)
# memory usage: 81.0+ KB

# %%
# 결측치 확인
null_index = business[business.isnull()].index
null_index
# Out:
# Index([   5,    7,    9,   12,   14,   15,   18,   20,   21,   28,
#        ...
#        2559, 2560, 2561, 2562, 2563, 2564, 2565, 2566, 2587, 2588],
#       dtype='int64', length=294)

# %%
# 결측치 삭제
business.drop(null_index, inplace=True)
name.drop(null_index, inplace=True)

# %%
print(business.shape, name.shape)
# Out:
# (2295,) (2295,)

# %% [markdown]
# #### 데이터 전처리
# - 형태소 분석
# - 한 글자 제거
# - 정규표현식 활용(숫자, 특수기호, 문장부호 등 삭제)

# %%
#### 형태소 분석기
# 장점 : 다른 형태소분석기에 비해 속도가 빠르다
# 단점 : 리눅스기반의 OS에서 활용할 수 있다

# %%
# okt 사용하기
from konlpy.tag import Okt

# %%
okt = Okt() # 분석기 객체 생성
for doc in tqdm(business):
    morphs = okt.morphs(doc) # 형태소 분석실시
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 2295/2295 [25:09<00:00,  1.52it/s]

# %%
# 문서 하나하나의 길이가 커서 okt로 처리하는데 시간이 걸린다
len(businessiness[0])

# %%
import pickle

# %%
with open('data/business_morphs.pkl', 'rb') as f:
    business_morphs = pickle.load(f)

# %%
business_morphs[0]
# Out:
# ['II',
#  '.',
#  '사업',
#  '의',
#  '내용',
#  '1',
#  '.',
#  '사업',
#  '의',
#  '개요',
#  '가',
#  '.',
#  '일반',
#  '적',
#  '인',
#  '사항',
#  '기업',
#  '회계',
#  '기준',
#  '서',
#  '제',
#  '1110',
#  '호',
#  '"',
#  '연결',
#  '재무제표',
#  '"',
#  '의',
#  '의하',
#  '여',
#  '2018',
#  '년',
#  '12',
#  '월',
#  '17',
#  '일',
#  '에',
#  '설립',
#  '한',
#  '동화',
#  '크립톤',
#  '기업가',
#  '정신',
#  '제일',
#  '호',
#  '창업',
#  '벤처',
#  '전문',
#  '사모',
#  '투자',
#  '합자회사',
#  '를',
#  '종속',
#  '회사',
#  '에',
#  '편입',
#  '하',
#  '였',
#  '습니다',
#  '.',
#  '나',
#  '.',
#  '지배',
#  '기업',
#  '의',
#  '현황',
#  '1',
#  ')',
#  '산업',
#  '의',
#  '특성',
#  '제약',
#  '산업',
#  '은',
#  '약학',
#  ',',
#  '화학',
#  ',',
#  '생물학',
#  '등',
#  '여러',
#  '분야',
#  '의',
#  '지식',
#  '과',
#  '기술',
#  '이',
#  '복합',
#  '적',
#  '으로',
#  '필요',
#  '한',
#  '기술',
#  '·',
#  '지식',
#  '집약',
#  '형',
#  '산업',
#  '으로',
#  '인간',
#  '의',
#  '생명',
#  '과',
#  '보건',
#  '에',
#  '직접',
#  '적',
#  '으로',
#  '관련',
#  '된',
#  '제품',
#  '을',
#  '생산',
#  '하',
#  '고',
#  ',',
#  '개발',
#  '·',
#  '제조',
#  '·',
#  '유통',
#  '·',
#  '가격',
#  '등',
#  '을',
#  '정부',
#  '에서',
#  '엄격',
#  '하',
#  '게',
#  '규제',
#  '하',
#  '고',
#  '관리',
#  '하',
#  '는',
#  '산업',
#  '적',
#  '특성',
#  '을',
#  '가지',
#  '고',
#  '있',
#  '습니다',
#  '.',
#  '또한',
#  '신약',
#  '개발',
#  '에',
#  '는',
#  '막대',
#  '한',
#  '시간',
#  '과',
#  '비용',
#  '이',
#  '소요',
#  '되',
#  '며',
#  ',',
#  '성공',
#  '확률',
#  '또한',
#  '높',
#  '지',
#  '않',
#  '으나',
#  '신약',
#  '개발',
#  '에',
#  '성공',
#  '할',
#  '경우',
#  '엔',
#  '엄청난',
#  '부',
#  '가',
#  '가치',
#  '를',
#  '창출',
#  '할',
#  '수',
#  '있',
#  '는',
#  '미래',
#  '성장산업',
#  '으로',
#  '분류',
#  '되',
#  '고',
#  '있',
#  '습니다',
#  '.',
#  '2',
#  ')',
#  '산업',
#  '의',
#  '성장',
#  '성',
#  '제약',
#  '산업',
#  '은',
#  '고령',
#  '화',
#  '시대',
#  '의',
#  '핵심',
#  '적',
#  '인',
#  '분야',
#  '로서',
#  '웰빙',
#  '경향',
#  '등',
#  '건강',
#  '한',
#  '노후',
#  '생활',
#  '에',
#  '대한',
#  '\xa0',
#  '관심',
#  '이',
#  '고조',
#  '되',
#  '면서',
#  '지속',
#  '적',
#  '인',
#  '성장',
#  '이',
#  '유망',
#  '한',
#  '산업',
#  '으로',
#  '인식',
#  '되',
#  '고',
#  '있',
#  '습니다',
#  '.',
#  '고령화',
#  '\xa0',
#  '\xa0\xa0',
#  '사회',
#  '로',
#  '의',
#  '진입',
#  ',',
#  '경제',
#  '수준',
#  '의',
#  '향상',
#  ',',
#  '난치병',
#  '치료',
#  '를',
#  '위한',
#  '생명',
#  '공학',
#  '을',
#  '기반',
#  '으로',
#  '하',
#  '는',
#  '신',
#  '\xa0',
#  '약',
#  '의',
#  '개발',
#  '등',
#  '은',
#  '국내',
#  '제약',
#  '산업',
#  '의',
#  '계속',
#  '적',
#  '인',
#  '성장',
#  '을',
#  '기대',
#  '하',
#  '게',
#  '하',
#  '는',
#  '중요',
#  '한',
#  '요소',
#  '입니다',
#  '.',
#  '3',
#  ')',
#  '경기',
#  '변동',
#  '의',
#  '특성',
#  '및',
#  '계절',
#  '성',
#  '제약',
#  '산업',
#  '은',
#  '산업',
#  '경기',
#  '측면',
#  '에서',
#  '수요',
#  '탄력',
#  '성',
#  '이',
#  '낮',
#  '고',
#  ',',
#  '경기',
#  '흐름',
#  '의',
#  '영향',
#  '을',
#  '덜',
#  '받',
#  '는',
#  '특성',
#  '을',
#  '가지',
#  '고',
#  '있',
#  '습니다',
#  '.',
#  '의약품',
#  '은',
#  '크',
#  '게',
#  '일반의약품',
#  '(',
#  'OTC',
#  ')',
#  '와',
#  '전문',
#  '의약품',
#  '(',
#  'ETC',
#  ')',
#  '로',
#  '구분',
#  '되',
#  '며',
#  '전문',
#  '의약품',
#  '은',
#  '의약',
#  '분업',
#  '이후',
#  '크',
#  '게',
#  '성장',
#  '하',
#  '고',
#  '있',
#  '으며',
#  ',',
#  '일반의약품',
#  '에',
#  '비해',
#  '경기',
#  '변동',
#  '과',
#  '계절',
#  '적',
#  '요인',
#  '등',
#  '에',
#  '영향',
#  '을',
#  '받',
#  '지',
#  '않',
#  '습니다',
#  '.',
#  '일반',
#  '의약품',
#  '의',
#  '경우',
#  '에',
#  '는',
#  '전문',
#  '의약품',
#  '보다',
#  '는',
#  '좀',
#  '더',
#  '경기',
#  '변동',
#  '과',
#  '계절',
#  '적',
#  '요인',
#  '에',
#  '따른',
#  '영향',
#  '을',
#  '받',
#  '고',
#  '있',
#  '습니다',
#  '.',
#  '4',
#  ')',
#  '경쟁',
#  '요소',
#  '자본',
#  '의',
#  '영세성',
#  '으로',
#  '인하',
#  '여',
#  '시장',
#  '진입',
#  '이',
#  '비교',
#  '적',
#  '용이',
#  '한',
#  '완전',
#  '경쟁',
#  '시장',
#  '으로',
#  '자본력',
#  ',',
#  '신약',
#  '개발력',
#  ',',
#  '오리지널',
#  '의약품',
#  '의',
#  '강점',
#  '을',
#  '보유',
#  '한',
#  '외국',
#  '계',
#  '제약사',
#  '들',
#  '이',
#  '시장',
#  '에서',
#  '약진',
#  '하',
#  '고',
#  '있',
#  '으며',
#  '원료',
#  '의약품',
#  ',',
#  '신약',
#  '개발',
#  ',',
#  '바이오산업',
#  '의',
#  '형태',
#  '로',
#  '대',
#  '기업',
#  '의',
#  '진출',
#  '이',
#  '가속',
#  '화',
#  '되',
#  '고',
#  '\xa0\xa0',
#  '있',
#  '습니다',
#  '.',
#  '또한',
#  '정부',
#  '의',
#  '약가',
#  '적',
#  '정화',
#  '정책',
#  '및',
#  '한',
#  '미',
#  'FTA',
#  '체결',
#  ',',
#  '약제',
#  '비',
#  '적정',
#  '화',
#  '방안',
#  '시행',
#  ',',
#  '기',
#  '등',
#  '재',
#  '의약품',
#  '목록',
#  '정비',
#  '사업',
#  ',',
#  'GMP',
#  '기준',
#  '선진',
#  '화',
#  '추진',
#  ',',
#  '비',
#  '윤리',
#  '적',
#  '영업',
#  '관행',
#  '금지',
#  '등',
#  '급변',
#  '하',
#  '는',
#  '경쟁',
#  '환경',
#  '속',
#  '에',
#  '각',
#  '제약사',
#  '별',
#  '실적',
#  '차별',
#  '화',
#  '가',
#  '예상',
#  '되',
#  '며',
#  '제품력',
#  ',',
#  '영업력',
#  '및',
#  '브랜드',
#  '인지',
#  '도',
#  '등',
#  '경쟁',
#  '요인',
#  '과',
#  '더불',
#  '어',
#  '신약',
#  '개발',
#  '력',
#  '및',
#  '수출',
#  '경쟁력',
#  '확보',
#  '여부',
#  '가',
#  '중요',
#  '한',
#  '핵심',
#  '쟁점',
#  '으로',
#  '부상',
#  '하',
#  '고',
#  '있',
#  '습니다',
#  '.',
#  '다',
#  '.',
#  '지배',
#  '회사',
#  '의',
#  '현황',
#  '1',
#  ')',
#  '영업',
#  '개황',
#  '및',
#  '사업',
#  '부문',
#  '의',
#  '구분',
#  '(',
#  '연결',
#  '기준',
#  ')',
#  '당사',
#  '의',
#  '91',
#  '기',
#  '매출액',
#  '은',
#  '307',
#  ',',
#  '150',
#  '백만',
#  '원',
#  '(',
#  '연결',
#  '기준',
#  ')',
#  '으로',
#  '전년',
#  '동기',
#  '대비',
#  '\xa0',
#  '0',
#  '.',
#  '2',
#  '%',
#  '증가',
#  '하',
#  '였으며',
#  '영업',
#  '이익',
#  '은',
#  '9',
#  ',',
#  '918',
#  '백만',
#  '원',
#  '(',
#  '연결',
#  '기준',
#  ')',
#  '으로',
#  '전년',
#  '동기',
#  '대비',
#  '\xa0',
#  '11',
#  '.',
#  '7',
#  '%',
#  '감소',
#  '하',
#  '였',
#  '습니다',
#  '.',
#  '제공',
#  '하',
#  '는',
#  '재화',
#  '나',
#  '용역',
#  '에',
#  '근거',
#  '하',
#  '여',
#  '영업',
#  '부문',
#  '을',
#  '구분',
#  '하',
#  '고',
#  '각',
#  '부문',
#  '의',
#  '재무',
#  '정보',
#  '를',
#  '내부',
#  '관리',
#  '목적',
#  '으로',
#  '활용',
#  '하',
#  '고',
#  '있',
#  '는',
#  '바',
#  ',',
#  '당사',
#  '는',
#  '제약',
#  '업',
#  ',',
#  '기타',
#  '금융업',
#  '등',
#  '을',
#  '영위',
#  '하',
#  '고',
#  '있',
#  '습니다',
#  '.',
#  '당기',
#  '와',
#  '전기',
#  '의',
#  '영업',
#  '부문',
#  '의',
#  '부문',
#  '별',
#  '정보',
#  '는',
#  '다음',
#  '과',
#  '같',
#  '습니다',
#  '.',
#  '(',
#  '단위',
#  ':',
#  '천',
#  '원',
#  ')',
#  '구',
#  '\xa0\xa0',
#  '분',
#  '제약',
#  '업',
#  '기타',
#  '금융업',
#  '연결',
#  '조정',
#  '합',
#  '\xa0\xa0',
#  '계',
#  '당기',
#  ':',
#  '총',
#  '매출액',
#  '307',
#  ',',
#  '150',
#  ',',
#  '026',
#  '-',
#  '-',
#  '307',
#  ',',
#  '150',
#  ',',
#  '026',
#  '순',
#  '매출액',
#  '307',
#  ',',
#  '150',
#  ',',
#  '026',
#  '-',
#  '-',
#  '307',
#  ',',
#  '150',
#  ',',
#  '026',
#  '영업',
#  '이익',
#  '10',
#  ',',
#  '056',
#  ',',
#  '453',
#  '(',
#  '138',
#  ',',
#  '707',
#  ')',
#  '-',
#  '9',
#  ',',
#  '917',
#  ',',
#  '746',
#  '자산',
#  '총액',
#  '376',
#  ',',
#  '466',
#  ',',
#  '089',
#  '4',
#  ',',
#  '262',
#  ',',
#  '464',
#  '(',
#  '4',
#  ',',
#  '700',
#  ',',
#  '000',
#  ')',
#  '376',
#  ',',
#  '028',
#  ',',
#  '553',
#  '전기',
#  ':',
#  '총',
#  '매출액',
#  '306',
#  ',',
#  '602',
#  ',',
#  '589',
#  '-',
#  '-',
#  '306',
#  ',',
#  '602',
#  ',',
#  '589',
#  '순',
#  '매출액',
#  '306',
#  ',',
#  '602',
#  ',',
#  '589',
#  '-',
#  '-',
#  '306',
#  ',',
#  '602',
#  ',',
#  '589',
#  '영업',
#  '이익',
#  '11',
#  ',',
#  '232',
#  ',',
#  '142',
#  '(',
#  '6',
#  ',',
#  '362',
#  ')',
#  '-',
#  '11',
#  ',',
#  '225',
#  ',',
#  '780',
#  '자산',
#  '총액',
#  '370',
#  ',',
#  '294',
#  ',',
#  '499',
#  '5',
#  ',',
#  '004',
#  ',',
#  '744',
#  '(',
#  '4',
#  ',',
#  '700',
#  ',',
#  '000',
#  ')',
#  '370',
#  ',',
#  '599',
#  ',',
#  '243',
#  '2',
#  ')',
#  '시장',
#  '점유',
#  '율',
#  '등',
#  '당사',
#  '가',
#  '자체',
#  '조사',
#  '한',
#  '제약',
#  '주요',
#  '업체',
#  '와',
#  '의',
#  '매출액',
#  '비교',
#  '는',
#  '다음',
#  '과',
#  '같',
#  '습니다',
#  '.',
#  '(',
#  '단위',
#  ':',
#  '백만',
#  '원',
#  ')',
#  '업',
#  '체',
#  '명',
#  '2019',
#  '년',
#  '2018',
#  '년',
#  '2017',
#  '년',
#  '유한양행',
#  '1',
#  ',',
#  '480',
#  ',',
#  '354',
#  '1',
#  ',',
#  '518',
#  ',',
#  '823',
#  '1',
#  ',',
#  '462',
#  ',',
#  '248',
#  '녹십자',
#  '1',
#  ',',
#  '369',
#  ',',
#  '710',
#  '1',
#  ',',
#  '334',
#  ',',
#  '878',
#  '1',
#  ',',
#  '287',
#  ',',
#  '916',
#  '대웅',
#  '제',
#  '약',
#  '1',
#  ',',
#  '113',
#  ',',
#  '425',
#  '1',
#  ',',
#  '031',
#  ',',
#  '427',
#  '960',
#  ',',
#  '307',
#  '보령',
#  '제',
#  '약',
#  '524',
#  ',',
#  '268',
#  '460',
#  ',',
#  '402',
#  '422',
#  ',',
#  '721',
#  '동화약품',
#  '307',
#  ',',
#  '150',
#  '306',
#  ',',
#  '603',
#  '258',
#  ',',
#  '882',
#  '[',
#  '자료',
#  '출처',
#  ':',
#  '금융',
#  '감독원',
#  '전자',
#  '공시',
#  '시스템',
#  '/',
#  '연결',
#  '재무제표',
#  '기준',
#  ']',
#  '3',
#  ')',
#  '회사',
#  '의',
#  '경쟁',
#  '상',
#  '우위',
#  '의약품',
#  '은',
#  '생산자',
#  '와',
#  '최종',
#  '소비자',
#  '사이',
#  ...]

# %%
# 1글자 데이터 제거 및 클렌징(숫자, 문장부호 제거) 실시
import re
p = re.compile("[0-9.,?!()@~]+")

# %%
business_clean = []
for doc in business_morphs:
    tmp = []
    for token in doc:
        if len(token) > 2:
            continue
        if p.match(token) :
            continue
        tmp.append(token)
    business_clean.append(tmp)

# %%
business_clean[0]
# Out:
# ['II',
#  '사업',
#  '의',
#  '내용',
#  '사업',
#  '의',
#  '개요',
#  '가',
#  '일반',
#  '적',
#  '인',
#  '사항',
#  '기업',
#  '회계',
#  '기준',
#  '서',
#  '제',
#  '호',
#  '"',
#  '연결',
#  '"',
#  '의',
#  '의하',
#  '여',
#  '년',
#  '월',
#  '일',
#  '에',
#  '설립',
#  '한',
#  '동화',
#  '정신',
#  '제일',
#  '호',
#  '창업',
#  '벤처',
#  '전문',
#  '사모',
#  '투자',
#  '를',
#  '종속',
#  '회사',
#  '에',
#  '편입',
#  '하',
#  '였',
#  '나',
#  '지배',
#  '기업',
#  '의',
#  '현황',
#  '산업',
#  '의',
#  '특성',
#  '제약',
#  '산업',
#  '은',
#  '약학',
#  '화학',
#  '등',
#  '여러',
#  '분야',
#  '의',
#  '지식',
#  '과',
#  '기술',
#  '이',
#  '복합',
#  '적',
#  '으로',
#  '필요',
#  '한',
#  '기술',
#  '·',
#  '지식',
#  '집약',
#  '형',
#  '산업',
#  '으로',
#  '인간',
#  '의',
#  '생명',
#  '과',
#  '보건',
#  '에',
#  '직접',
#  '적',
#  '으로',
#  '관련',
#  '된',
#  '제품',
#  '을',
#  '생산',
#  '하',
#  '고',
#  '개발',
#  '·',
#  '제조',
#  '·',
#  '유통',
#  '·',
#  '가격',
#  '등',
#  '을',
#  '정부',
#  '에서',
#  '엄격',
#  '하',
#  '게',
#  '규제',
#  '하',
#  '고',
#  '관리',
#  '하',
#  '는',
#  '산업',
#  '적',
#  '특성',
#  '을',
#  '가지',
#  '고',
#  '있',
#  '또한',
#  '신약',
#  '개발',
#  '에',
#  '는',
#  '막대',
#  '한',
#  '시간',
#  '과',
#  '비용',
#  '이',
#  '소요',
#  '되',
#  '며',
#  '성공',
#  '확률',
#  '또한',
#  '높',
#  '지',
#  '않',
#  '으나',
#  '신약',
#  '개발',
#  '에',
#  '성공',
#  '할',
#  '경우',
#  '엔',
#  '부',
#  '가',
#  '가치',
#  '를',
#  '창출',
#  '할',
#  '수',
#  '있',
#  '는',
#  '미래',
#  '으로',
#  '분류',
#  '되',
#  '고',
#  '있',
#  '산업',
#  '의',
#  '성장',
#  '성',
#  '제약',
#  '산업',
#  '은',
#  '고령',
#  '화',
#  '시대',
#  '의',
#  '핵심',
#  '적',
#  '인',
#  '분야',
#  '로서',
#  '웰빙',
#  '경향',
#  '등',
#  '건강',
#  '한',
#  '노후',
#  '생활',
#  '에',
#  '대한',
#  '\xa0',
#  '관심',
#  '이',
#  '고조',
#  '되',
#  '면서',
#  '지속',
#  '적',
#  '인',
#  '성장',
#  '이',
#  '유망',
#  '한',
#  '산업',
#  '으로',
#  '인식',
#  '되',
#  '고',
#  '있',
#  '\xa0',
#  '\xa0\xa0',
#  '사회',
#  '로',
#  '의',
#  '진입',
#  '경제',
#  '수준',
#  '의',
#  '향상',
#  '치료',
#  '를',
#  '위한',
#  '생명',
#  '공학',
#  '을',
#  '기반',
#  '으로',
#  '하',
#  '는',
#  '신',
#  '\xa0',
#  '약',
#  '의',
#  '개발',
#  '등',
#  '은',
#  '국내',
#  '제약',
#  '산업',
#  '의',
#  '계속',
#  '적',
#  '인',
#  '성장',
#  '을',
#  '기대',
#  '하',
#  '게',
#  '하',
#  '는',
#  '중요',
#  '한',
#  '요소',
#  '경기',
#  '변동',
#  '의',
#  '특성',
#  '및',
#  '계절',
#  '성',
#  '제약',
#  '산업',
#  '은',
#  '산업',
#  '경기',
#  '측면',
#  '에서',
#  '수요',
#  '탄력',
#  '성',
#  '이',
#  '낮',
#  '고',
#  '경기',
#  '흐름',
#  '의',
#  '영향',
#  '을',
#  '덜',
#  '받',
#  '는',
#  '특성',
#  '을',
#  '가지',
#  '고',
#  '있',
#  '은',
#  '크',
#  '게',
#  '와',
#  '전문',
#  '로',
#  '구분',
#  '되',
#  '며',
#  '전문',
#  '은',
#  '의약',
#  '분업',
#  '이후',
#  '크',
#  '게',
#  '성장',
#  '하',
#  '고',
#  '있',
#  '으며',
#  '에',
#  '비해',
#  '경기',
#  '변동',
#  '과',
#  '계절',
#  '적',
#  '요인',
#  '등',
#  '에',
#  '영향',
#  '을',
#  '받',
#  '지',
#  '않',
#  '일반',
#  '의',
#  '경우',
#  '에',
#  '는',
#  '전문',
#  '보다',
#  '는',
#  '좀',
#  '더',
#  '경기',
#  '변동',
#  '과',
#  '계절',
#  '적',
#  '요인',
#  '에',
#  '따른',
#  '영향',
#  '을',
#  '받',
#  '고',
#  '있',
#  '경쟁',
#  '요소',
#  '자본',
#  '의',
#  '으로',
#  '인하',
#  '여',
#  '시장',
#  '진입',
#  '이',
#  '비교',
#  '적',
#  '용이',
#  '한',
#  '완전',
#  '경쟁',
#  '시장',
#  '으로',
#  '신약',
#  '의',
#  '강점',
#  '을',
#  '보유',
#  '한',
#  '외국',
#  '계',
#  '들',
#  '이',
#  '시장',
#  '에서',
#  '약진',
#  '하',
#  '고',
#  '있',
#  '으며',
#  '원료',
#  '신약',
#  '개발',
#  '의',
#  '형태',
#  '로',
#  '대',
#  '기업',
#  '의',
#  '진출',
#  '이',
#  '가속',
#  '화',
#  '되',
#  '고',
#  '\xa0\xa0',
#  '있',
#  '또한',
#  '정부',
#  '의',
#  '약가',
#  '적',
#  '정화',
#  '정책',
#  '및',
#  '한',
#  '미',
#  '체결',
#  '약제',
#  '비',
#  '적정',
#  '화',
#  '방안',
#  '시행',
#  '기',
#  '등',
#  '재',
#  '목록',
#  '정비',
#  '사업',
#  '기준',
#  '선진',
#  '화',
#  '추진',
#  '비',
#  '윤리',
#  '적',
#  '영업',
#  '관행',
#  '금지',
#  '등',
#  '급변',
#  '하',
#  '는',
#  '경쟁',
#  '환경',
#  '속',
#  '에',
#  '각',
#  '별',
#  '실적',
#  '차별',
#  '화',
#  '가',
#  '예상',
#  '되',
#  '며',
#  '및',
#  '인지',
#  '도',
#  '등',
#  '경쟁',
#  '요인',
#  '과',
#  '더불',
#  '어',
#  '신약',
#  '개발',
#  '력',
#  '및',
#  '수출',
#  '확보',
#  '여부',
#  '가',
#  '중요',
#  '한',
#  '핵심',
#  '쟁점',
#  '으로',
#  '부상',
#  '하',
#  '고',
#  '있',
#  '다',
#  '지배',
#  '회사',
#  '의',
#  '현황',
#  '영업',
#  '개황',
#  '및',
#  '사업',
#  '부문',
#  '의',
#  '구분',
#  '연결',
#  '기준',
#  '당사',
#  '의',
#  '기',
#  '은',
#  '백만',
#  '원',
#  '연결',
#  '기준',
#  '으로',
#  '전년',
#  '동기',
#  '대비',
#  '\xa0',
#  '%',
#  '증가',
#  '하',
#  '영업',
#  '이익',
#  '은',
#  '백만',
#  '원',
#  '연결',
#  '기준',
#  '으로',
#  '전년',
#  '동기',
#  '대비',
#  '\xa0',
#  '%',
#  '감소',
#  '하',
#  '였',
#  '제공',
#  '하',
#  '는',
#  '재화',
#  '나',
#  '용역',
#  '에',
#  '근거',
#  '하',
#  '여',
#  '영업',
#  '부문',
#  '을',
#  '구분',
#  '하',
#  '고',
#  '각',
#  '부문',
#  '의',
#  '재무',
#  '정보',
#  '를',
#  '내부',
#  '관리',
#  '목적',
#  '으로',
#  '활용',
#  '하',
#  '고',
#  '있',
#  '는',
#  '바',
#  '당사',
#  '는',
#  '제약',
#  '업',
#  '기타',
#  '등',
#  '을',
#  '영위',
#  '하',
#  '고',
#  '있',
#  '당기',
#  '와',
#  '전기',
#  '의',
#  '영업',
#  '부문',
#  '의',
#  '부문',
#  '별',
#  '정보',
#  '는',
#  '다음',
#  '과',
#  '같',
#  '단위',
#  ':',
#  '천',
#  '원',
#  '구',
#  '\xa0\xa0',
#  '분',
#  '제약',
#  '업',
#  '기타',
#  '연결',
#  '조정',
#  '합',
#  '\xa0\xa0',
#  '계',
#  '당기',
#  ':',
#  '총',
#  '-',
#  '-',
#  '순',
#  '-',
#  '-',
#  '영업',
#  '이익',
#  '-',
#  '자산',
#  '총액',
#  '전기',
#  ':',
#  '총',
#  '-',
#  '-',
#  '순',
#  '-',
#  '-',
#  '영업',
#  '이익',
#  '-',
#  '자산',
#  '총액',
#  '시장',
#  '점유',
#  '율',
#  '등',
#  '당사',
#  '가',
#  '자체',
#  '조사',
#  '한',
#  '제약',
#  '주요',
#  '업체',
#  '와',
#  '의',
#  '비교',
#  '는',
#  '다음',
#  '과',
#  '같',
#  '단위',
#  ':',
#  '백만',
#  '원',
#  '업',
#  '체',
#  '명',
#  '년',
#  '년',
#  '년',
#  '대웅',
#  '제',
#  '약',
#  '보령',
#  '제',
#  '약',
#  '[',
#  '자료',
#  '출처',
#  ':',
#  '금융',
#  '전자',
#  '공시',
#  '/',
#  '연결',
#  '기준',
#  ']',
#  '회사',
#  '의',
#  '경쟁',
#  '상',
#  '우위',
#  '은',
#  '와',
#  '최종',
#  '사이',
#  '에',
#  '의사',
#  '및',
#  '약사',
#  '가',
#  '연결',
#  '고리',
#  '역할',
#  '을',
#  '하',
#  '므로',
#  '이',
#  '들',
#  '의',
#  '취향',
#  '및',
#  '소견',
#  '에',
#  '의해',
#  '소비',
#  '가',
#  '영향',
#  '을',
#  '많이',
#  '받',
#  '는',
#  '경향',
#  '이',
#  '있',
#  '주요',
#  '목표',
#  '시장',
#  '은',
#  '병',
#  '의원',
#  '및',
#  '약국',
#  '이',
#  '며',
#  '의사',
#  '및',
#  '약사',
#  '가',
#  '주요',
#  '대상',
#  '이',
#  '\xa0',
#  '당사',
#  '의',
#  '일반',
#  '은',
#  '회사',
#  '설립',
#  '당시',
#  '부터',
#  '생산',
#  '된',
#  '활',
#  '명수',
#  '류',
#  '가',
#  '까스',
#  '활',
#  '명수',
#  '큐',
#  '를',
#  '중심',
#  '으로',
#  '한',
#  '고정',
#  '를',
#  '확보',
#  '하',
#  '여',
#  '액제',
#  '의',
#  '선두',
#  '를',
#  '유지',
#  '하',
#  '고',
#  '있',
#  '으며',
#  '후시',
#  '딘',
#  '연고',
#  '판',
#  '콜',
#  '잇',
#  '치',
#  '등',
#  '일반',
#  '대중',
#  '에게',
#  '가',
#  '높',
#  '은',
#  '주력',
#  '제품',
#  '이',
#  '양호',
#  '한',
#  '시장',
#  '지위',
#  '를',
#  '유지',
#  '하',
#  '고',
#  '있',
#  '전문',
#  '시장',
#  '은',
#  '지속',
#  '적',
#  '인',
#  '환경',
#  '변화',
#  '요인',
#  '이',
#  '발생',
#  '하',
#  '고',
#  '있',
#  '으며',
#  '이러',
#  '한',
#  '환경',
#  '속',
#  '에서',
#  '준법',
#  '경영',
#  '을',
#  '위해',
#  'CP',
#  '공정',
#  '거래',
#  '자율',
#  '준수',
#  '운영',
#  '을',
#  '강화',
#  '하',
#  '는',
#  '동시',
#  '에',
#  '제품',
#  '및',
#  '강화',
#  '를',
#  '통한',
#  '확보',
#  '에',
#  '중점',
#  '을',
#  '두',
#  '고',
#  '있',
#  '신규',
#  '사업',
#  '등',
#  '의',
#  '내용',
#  '및',
#  '전망',
#  '해당',
#  '사항',
#  '없',
#  '음',
#  '라',
#  '종속',
#  '회사',
#  '의',
#  '현황',
#  '연결',
#  '대상',
#  '종속',
#  '기업',
#  '의',
#  '개요',
#  '종속',
#  '회사',
#  '동화',
#  '정신',
#  '제일',
#  '호',
#  '창업',
#  '벤처',
#  '전문',
#  '사모',
#  '투자',
#  '는',
#  '자본',
#  '시장',
#  '과',
#  '금융',
#  '투자',
#  '업',
#  '에',
#  '관한',
#  '법률',
#  '이하',
#  '자본',
#  '제',
#  '조',
#  '제',
#  '항',
#  '제',
#  '호',
#  '에',
#  '의한',
#  '사모',
#  '투자',
#  '전문',
#  '회사',
#  '로서',
#  '종속',
#  '회사',
#  '의',
#  '주식',
#  '또는',
#  '지분',
#  '등',
#  '을',
#  '투자',
#  '하',
#  '여',
#  '경영',
#  '권',
#  '참여',
#  '사업',
#  '구조',
#  '또는',
#  '지배',
#  '구조',
#  '개선',
#  '등',
#  '에',
#  '투자',
#  '및',
#  '운용',
#  '하',
#  '며',
#  '그',
#  '수익',
#  '을',
#  '사원',
#  '에게',
#  '분배',
#  '하',
#  '는',
#  '것',
#  '을',
#  '목적',
#  '으로',
#  '기',
#  '업명',
#  '업종',
#  '지분',
#  '율',
#  '%)',
#  '기말',
#  '기말',
#  '동화',
#  '기업',
#  '가정',
#  '신제',
#  '일',
#  '호',
#  '창업',
#  '벤처',
#  '전문',
#  '사모',
#  '투자',
#  '월',
#  '일',
#  '사모',
#  '투자',
#  '전문',
#  '회사',
#  '당기',
#  '말',
#  '현재',
#  '종속',
#  '기업',
#  '의',
#  '요약',
#  '재무',
#  '정보',
#  '단위',
#  ':',
#  '백만',
#  '원',
#  '기',
#  '업명',
#  '자산',
#  '부채',
#  '자본',
#  '매출',
#  '당기',
#  '순',
#  '손익',
#  '총',
#  '포괄',
#  '손익',
#  '동화',
#  '기업',
#  '가정',
#  '신제',
#  '일',
#  '호',
#  '창업',
#  '벤처',
#  '전문',
#  '사모',
#  '투자',
#  '-',
#  '-',
#  '종속',
#  '기업',
#  '의',
#  '투자',
#  '현황',
#  '단위',
#  ':',
#  '원',
#  '회사',
#  '명',
#  '수량',
#  ...]

# %% [markdown]
# #### 유사도 비교를 위해 수치데이터로 변경
# - 빈도기반의 tf-idf를 이용해서 수치화

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
business_tfidf = TfidfVectorizer(min_df = 5)
business_data = [" ".join(doc) for doc in business_clean]
business_tfidf.fit(business_data)
business_vector = business_tfidf.transform(business_data)
business_vector.shape
# Out:
# (2295, 14560)

# %% [markdown]
# ## case1
# #### 유사도 계산하기
# - 유클리디언 거리공식, 맨하튼 거리공식
# - 코사인 유사도

# %%
# 코사인 유사도 공식
import numpy as np
from numpy import dot
from numpy.linalg import norm

def cos_sim(A, B):
    return dot(A, B)/(norm(A)*norm(B))

doc1 = np.array([0,1,1,1])
doc2 = np.array([1,0,1,1])
doc3 = np.array([2,0,2,2])

print('문서 1과 문서2의 유사도 :',cos_sim(doc1, doc2))
print('문서 1과 문서3의 유사도 :',cos_sim(doc1, doc3))
print('문서 2와 문서3의 유사도 :',cos_sim(doc2, doc3))
# Out:
# 문서 1과 문서2의 유사도 : 0.6666666666666667
# 문서 1과 문서3의 유사도 : 0.6666666666666667
# 문서 2와 문서3의 유사도 : 1.0000000000000002

# %%
print(name[:2])
# Out:
# 0     동화약품
# 1    KR모터스
# Name: name, dtype: object

# %%
cos_sim(business_vector[0].toarray()[0],
       business_vector[1].toarray()[0])
# Out:
# 0.2427018666779161

# %%
print(name[:30])
# Out:
# 0          동화약품
# 1         KR모터스
# 2            경방
# 3         메리츠화재
# 4         삼양홀딩스
# 6         하이트진로
# 8          유한양행
# 10       CJ대한통운
# 11     하이트진로홀딩스
# 13           두산
# 16       성창기업지주
# 17         대림산업
# 19         유유제약
# 22        일동홀딩스
# 23    한국테크놀로지그룹
# 24        삼천당제약
# 25          기아차
# 26        대유플러스
# 27        노루홀딩스
# 29       한화손해보험
# 30        삼화페인트
# 31       롯데손해보험
# 32         대원강업
# 33       중앙에너비스
# 34         조선내화
# 35         대동공업
# 36         가온전선
# 37         삼일제약
# 38         흥국화재
# 41        CS홀딩스
# Name: name, dtype: object

# %%
name.iloc[[5,8]]
# Out:
# 6        하이트진로
# 11    하이트진로홀딩스
# Name: name, dtype: object

# %%
cos_sim(business_vector[5].toarray()[0],
       business_vector[8].toarray()[0])
# Out:
# 0.9792141276929426

# %%
# 전체데이터 유사도 구하기
from sklearn.metrics.pairwise import cosine_similarity

# %%
cosine_sim = cosine_similarity(business_vector, business_vector)
cosine_sim.shape
# Out:
# (2295, 2295)

# %%
cosine_sim[5]
# Out:
# array([0.16758042, 0.18681909, 0.20712347, ..., 0.11864448, 0.14061619,
#        0.08683308])

# %%
sim_df = pd.DataFrame(cosine_sim[5])
sim_df['기업명'] = name.values
sim_df.sort_values(by=0, inplace=True, ascending=False)
sim_df.head()
# Out:
#             0       기업명
# 5    1.000000     하이트진로
# 8    0.979214  하이트진로홀딩스
# 233  0.509183      롯데칠성
# 42   0.505201      보해양조
# 720  0.501673        무학

# %% [markdown]
# ## case2
# - 딥러닝 모델 활용 : Doc2vec
# - Word2vec 이후에 후속 모델로 공개된 것 (2014년 구글 연구팀이 발표)

# %% [markdown]
# ## Distributed Memory version of Pharagraph Vector (PV-DM)

# %% [markdown]
# ![image.png](attachment:a7575b74-9587-4e53-8eb4-4cc2f8d6e826.png)

# %% [markdown]
# ## Distributed Bag of Words version of Paragraph Vector (PV-DBOW)

# %% [markdown]
# ![image.png](attachment:6d49c394-5388-4769-a81b-2bb9dd86b973.png)

# %% [markdown]
# #### 데이터셋 구성하기

# %%
from gensim.models.doc2vec import TaggedDocument # Doc2vec에 학습시키기위해 사용하는
from gensim.models import Doc2Vec # Doc2Vec 클래스

# %%
business_data_for_d2v = [] # doc2vec을 위한 전체데이터가 들어갈 리스트
for doc, n in zip(business_clean, name):
    obj = TaggedDocument(tags = n, words = doc) # 기업명하고 공시테스트를 하나로 묶어줌
    business_data_for_d2v.append(obj)

# %%
business_data_for_d2v[0]
# Out:
# TaggedDocument(words=['II', '사업', '의', '내용', '사업', '의', '개요', '가', '일반', '적', '인', '사항', '기업', '회계', '기준', '서', '제', '호', '"', '연결', '"', '의', '의하', '여', '년', '월', '일', '에', '설립', '한', '동화', '정신', '제일', '호', '창업', '벤처', '전문', '사모', '투자', '를', '종속', '회사', '에', '편입', '하', '였', '나', '지배', '기업', '의', '현황', '산업', '의', '특성', '제약', '산업', '은', '약학', '화학', '등', '여러', '분야', '의', '지식', '과', '기술', '이', '복합', '적', '으로', '필요', '한', '기술', '·', '지식', '집약', '형', '산업', '으로', '인간', '의', '생명', '과', '보건', '에', '직접', '적', '으로', '관련', '된', '제품', '을', '생산', '하', '고', '개발', '·', '제조', '·', '유통', '·', '가격', '등', '을', '정부', '에서', '엄격', '하', '게', '규제', '하', '고', '관리', '하', '는', '산업', '적', '특성', '을', '가지', '고', '있', '또한', '신약', '개발', '에', '는', '막대', '한', '시간', '과', '비용', '이', '소요', '되', '며', '성공', '확률', '또한', '높', '지', '않', '으나', '신약', '개발', '에', '성공', '할', '경우', '엔', '부', '가', '가치', '를', '창출', '할', '수', '있', '는', '미래', '으로', '분류', '되', '고', '있', '산업', '의', '성장', '성', '제약', '산업', '은', '고령', '화', '시대', '의', '핵심', '적', '인', '분야', '로서', '웰빙', '경향', '등', '건강', '한', '노후', '생활', '에', '대한', '\xa0', '관심', '이', '고조', '되', '면서', '지속', '적', '인', '성장', '이', '유망', '한', '산업', '으로', '인식', '되', '고', '있', '\xa0', '\xa0\xa0', '사회', '로', '의', '진입', '경제', '수준', '의', '향상', '치료', '를', '위한', '생명', '공학', '을', '기반', '으로', '하', '는', '신', '\xa0', '약', '의', '개발', '등', '은', '국내', '제약', '산업', '의', '계속', '적', '인', '성장', '을', '기대', '하', '게', '하', '는', '중요', '한', '요소', '경기', '변동', '의', '특성', '및', '계절', '성', '제약', '산업', '은', '산업', '경기', '측면', '에서', '수요', '탄력', '성', '이', '낮', '고', '경기', '흐름', '의', '영향', '을', '덜', '받', '는', '특성', '을', '가지', '고', '있', '은', '크', '게', '와', '전문', '로', '구분', '되', '며', '전문', '은', '의약', '분업', '이후', '크', '게', '성장', '하', '고', '있', '으며', '에', '비해', '경기', '변동', '과', '계절', '적', '요인', '등', '에', '영향', '을', '받', '지', '않', '일반', '의', '경우', '에', '는', '전문', '보다', '는', '좀', '더', '경기', '변동', '과', '계절', '적', '요인', '에', '따른', '영향', '을', '받', '고', '있', '경쟁', '요소', '자본', '의', '으로', '인하', '여', '시장', '진입', '이', '비교', '적', '용이', '한', '완전', '경쟁', '시장', '으로', '신약', '의', '강점', '을', '보유', '한', '외국', '계', '들', '이', '시장', '에서', '약진', '하', '고', '있', '으며', '원료', '신약', '개발', '의', '형태', '로', '대', '기업', '의', '진출', '이', '가속', '화', '되', '고', '\xa0\xa0', '있', '또한', '정부', '의', '약가', '적', '정화', '정책', '및', '한', '미', '체결', '약제', '비', '적정', '화', '방안', '시행', '기', '등', '재', '목록', '정비', '사업', '기준', '선진', '화', '추진', '비', '윤리', '적', '영업', '관행', '금지', '등', '급변', '하', '는', '경쟁', '환경', '속', '에', '각', '별', '실적', '차별', '화', '가', '예상', '되', '며', '및', '인지', '도', '등', '경쟁', '요인', '과', '더불', '어', '신약', '개발', '력', '및', '수출', '확보', '여부', '가', '중요', '한', '핵심', '쟁점', '으로', '부상', '하', '고', '있', '다', '지배', '회사', '의', '현황', '영업', '개황', '및', '사업', '부문', '의', '구분', '연결', '기준', '당사', '의', '기', '은', '백만', '원', '연결', '기준', '으로', '전년', '동기', '대비', '\xa0', '%', '증가', '하', '영업', '이익', '은', '백만', '원', '연결', '기준', '으로', '전년', '동기', '대비', '\xa0', '%', '감소', '하', '였', '제공', '하', '는', '재화', '나', '용역', '에', '근거', '하', '여', '영업', '부문', '을', '구분', '하', '고', '각', '부문', '의', '재무', '정보', '를', '내부', '관리', '목적', '으로', '활용', '하', '고', '있', '는', '바', '당사', '는', '제약', '업', '기타', '등', '을', '영위', '하', '고', '있', '당기', '와', '전기', '의', '영업', '부문', '의', '부문', '별', '정보', '는', '다음', '과', '같', '단위', ':', '천', '원', '구', '\xa0\xa0', '분', '제약', '업', '기타', '연결', '조정', '합', '\xa0\xa0', '계', '당기', ':', '총', '-', '-', '순', '-', '-', '영업', '이익', '-', '자산', '총액', '전기', ':', '총', '-', '-', '순', '-', '-', '영업', '이익', '-', '자산', '총액', '시장', '점유', '율', '등', '당사', '가', '자체', '조사', '한', '제약', '주요', '업체', '와', '의', '비교', '는', '다음', '과', '같', '단위', ':', '백만', '원', '업', '체', '명', '년', '년', '년', '대웅', '제', '약', '보령', '제', '약', '[', '자료', '출처', ':', '금융', '전자', '공시', '/', '연결', '기준', ']', '회사', '의', '경쟁', '상', '우위', '은', '와', '최종', '사이', '에', '의사', '및', '약사', '가', '연결', '고리', '역할', '을', '하', '므로', '이', '들', '의', '취향', '및', '소견', '에', '의해', '소비', '가', '영향', '을', '많이', '받', '는', '경향', '이', '있', '주요', '목표', '시장', '은', '병', '의원', '및', '약국', '이', '며', '의사', '및', '약사', '가', '주요',  ...

# %% [markdown]
# #### 모델생성 및 학습

# %%
model = Doc2Vec(vector_size=300, # 문서를 수치화할때 사용할 숫자의 크기
               alpha = 0.025, # 학습률
               min_alpha = 0.0025, # 학습률 감소
               window=8) # 학습시 다음단어를 맞추기 위한 입력단어의 갯수

# %%
# 사용하는 단어사전 구축
model.build_vocab(business_data_for_d2v)

# %%
# 사용하는 문서의 수 확인
model.corpus_count
# Out:
# 2295

# %%
model.raw_vocab
# Out:
# defaultdict(int, {})

# %%
# 학습
model.train(business_data_for_d2v, # 학습에 사용할 문서데이터 셋
           total_examples=model.corpus_count, # 전체 사용하는 문서의 수
           epochs=20) # 업데이트 수

# %%
# Doc2vec의 유사도계산 함수 -> tag에 넣은 문서명을 기준으로 유사도비교 실시
model.dv.most_similar("하이트진로")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[102], line 2
#       1 # Doc2vec의 유사도계산 함수 -> tag에 넣은 문서명을 기준으로 유사도비교 실시
# ----> 2 model.dv.most_similar("하이트진로")
#
# File ~\anaconda3\Lib\site-packages\gensim\models\keyedvectors.py:841, in KeyedVectors.most_similar(self, positive, negative, topn, clip_start, clip_end, restrict_vocab, indexer)
#     838         weight[idx] = item[1]
#     840 # compute the weighted average of all keys
# --> 841 mean = self.get_mean_vector(keys, weight, pre_normalize=True, post_normalize=True, ignore_missing=False)
#     842 all_keys = [
#     843     self.get_index(key) for key in keys if isinstance(key, _KEY_TYPES) and self.has_index_for(key)
#     844 ]
#     846 if indexer is not None and isinstance(topn, int):
#
# File ~\anaconda3\Lib\site-packages\gensim\models\keyedvectors.py:518, in KeyedVectors.get_mean_vector(self, keys, weights, pre_normalize, post_normalize, ignore_missing)
#     516         total_weight += abs(weights[idx])
#     517     elif not ignore_missing:
# --> 518         raise KeyError(f"Key '{key}' not present in vocabulary")
#     520 if total_weight > 0:
#     521     mean = mean / total_weight
#
# KeyError: "Key '하이트진로' not present in vocabulary"

# %%
# 기업명 확인 후 다른 우사도 구해보기
model.dv.most_similar('카카오')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[103], line 2
#       1 # 기업명 확인 후 다른 우사도 구해보기
# ----> 2 model.dv.most_similar('카카오')
#
# File ~\anaconda3\Lib\site-packages\gensim\models\keyedvectors.py:841, in KeyedVectors.most_similar(self, positive, negative, topn, clip_start, clip_end, restrict_vocab, indexer)
#     838         weight[idx] = item[1]
#     840 # compute the weighted average of all keys
# --> 841 mean = self.get_mean_vector(keys, weight, pre_normalize=True, post_normalize=True, ignore_missing=False)
#     842 all_keys = [
#     843     self.get_index(key) for key in keys if isinstance(key, _KEY_TYPES) and self.has_index_for(key)
#     844 ]
#     846 if indexer is not None and isinstance(topn, int):
#
# File ~\anaconda3\Lib\site-packages\gensim\models\keyedvectors.py:518, in KeyedVectors.get_mean_vector(self, keys, weights, pre_normalize, post_normalize, ignore_missing)
#     516         total_weight += abs(weights[idx])
#     517     elif not ignore_missing:
# --> 518         raise KeyError(f"Key '{key}' not present in vocabulary")
#     520 if total_weight > 0:
#     521     mean = mean / total_weight
#
# KeyError: "Key '카카오' not present in vocabulary"
